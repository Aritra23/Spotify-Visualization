# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
file = 'data.csv'

# %%
spotify_df = pd.read_csv(file)
spotify_df
# Out:
#          Position                                  Track Name  \
# 0               1                  Reggaetón Lento (Bailemos)
# 1               2                                    Chantaje
# 2               3                   Otra Vez (feat. J Balvin)
# 3               4                                Vente Pa' Ca
# 4               5                                      Safari
# 5               6                                La Bicicleta
# 6               7                                  Ay Mi Dios
# 7               8                          Andas En Mi Cabeza
# 8               9                                 Traicionera
# 9              10                                 Shaky Shaky
# 10             11                                  Vacaciones
# 11             12                      Dile Que Tu Me Quieres
# 12             13                             Let Me Love You
# 13             14                            DUELE EL CORAZON
# ...

# %%
region_group = spotify_df.groupby("Region").nlargest(100).reset_index(drop=True)
//groupbyregion_df = region_group.sort_values(ascending=False).head(100).reset_index(drop=True)
region_group
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-987d0506a339> in <module>()
#       1 region_group = spotify_df.groupby("Region")
# ----> 2 groupbyregion_df = region_group.sort_values(ascending=False).head(100).reset_index(drop=True)
#       3 region_group
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# ...

# %%
region_group.to_csv('spotif_data.csv')

# %%
csv_database = create_engine('sqlite:///csv_spotify.db')

# %%
chunksize = 100000
i = 0
j = 1
for df in pd.read_csv(file, chunksize=chunksize, iterator=True):
      df = df.rename(columns={c: c.replace(' ', '') for c in df.columns}) 
      df.index += j
      i+=1
      df.to_sql('table', csv_database, if_exists='append')
      j = df.index[-1] + 1

# %%
df = pd.read_sql_query('SELECT * from table LIMIT 100', csv_database)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# OperationalError: near "table": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-fa08e1186bb5> in <module>()
# ...
